# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
sns.set()

# %%
Fortune10_2017 = pd.read_csv('./Resources/Fortune10_2017.csv')
Fortune10_2017 = Fortune10_2017.drop(columns={"Profits", "Ticker"})
Fortune10_2017
# Out:
#    Rank             Company  Revenues
# 0     1             Walmart    485873
# 1     2  Berkshire Hathaway    223604
# 2     3               Apple    215639
# 3     4         Exxon Mobil    205004
# 4     5            McKesson    192487
# 5     6  UnitedHealth Group    184840
# 6     7          CVS Health    177526
# 7     8      General Motors    166380
# 8     9                AT&T    163786
# 9    10          Ford Motor    151800

# %%
Fortune10_2016 = pd.read_csv('./Resources/Fortune10_2016.csv')
Fortune10_2016 = Fortune10_2016.drop(columns={"Ticker"})
Fortune10_2016
# Out:
#    Rank             Company  Revenues
# 0     1             Walmart    482130
# 1     2         Exxon Mobil    246204
# 2     3               Apple    233715
# 3     4  Berkshire Hathaway    210821
# 4     5            McKesson    181241
# 5     6  UnitedHealth Group    157107
# 6     7          CVS Health    153290
# 7     8      General Motors    152356
# 8     9          Ford Motor    149558
# 9    10                AT&T    146801

# %%
merge_table = pd.merge(Fortune10_2016, Fortune10_2017, on="Company")
merge_table.columns
# Out:
# Index(['Rank_x', 'Company', 'Revenues_x', 'Rank_y', 'Revenues_y'], dtype='object')

# %%
merge_table.rename(columns={"Rank_x":"Rank 2016", "Revenues_x":"Revenue 2016",
                                "Rank_y":"Rank 2017", "Revenues_y":"Revenues 2017"})
# Out:
#    Rank 2016             Company  Revenue 2016  Rank 2017  Revenues 2017
# 0          1             Walmart        482130          1         485873
# 1          2         Exxon Mobil        246204          4         205004
# 2          3               Apple        233715          3         215639
# 3          4  Berkshire Hathaway        210821          2         223604
# 4          5            McKesson        181241          5         192487
# 5          6  UnitedHealth Group        157107          6         184840
# 6          7          CVS Health        153290          7         177526
# 7          8      General Motors        152356          8         166380
# 8          9          Ford Motor        149558         10         151800
# 9         10                AT&T        146801          9         163786

# %%
multi_plot = merge_table.plot(kind="bar", figsize=(20,5), color=colors)

multi_plot.set_xticklabels(merge_table["Company"], rotation=45, color='r', fontsize='20')

plt.show()
plt.tight_layout()
plt.savefig("Resources/Top10_Multi_Year.png")
# Out:
# <img src="data:image/png;base64,..." width="2000">
